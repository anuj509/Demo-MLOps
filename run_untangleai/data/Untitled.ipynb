# %%
import pandas as pd

# %%
X_test = pd.read_csv('val_X.csv')

# %%
X_test.head(10)
# Out:
#    Goal Scored  Ball Possession %  Attempts  On-Target  Off-Target  Blocked  \
# 0            0                 60         9          3           5        1
# 1            2                 47        21         10           7        4
# 2            2                 59        13          5           6        2
# 3            2                 71        16          5           4        7
# 4            1                 53        13          1           8        4
# 5            2                 38        13          7           4        2
# 6            2                 54        22          7          11        4
# 7            0                 53        16          4          10        2
# 8            2                 43         8          2           4        2
# 9            2                 58        20          5           8        7
#
#    Corners  Offsides  Free Kicks  Saves  Pass Accuracy %  Passes  \
# 0        5         1           7      4               90     629
# ...

# %%
X_test.iloc[0]
# Out:
# Goal Scored                 0
# Ball Possession %          60
# Attempts                    9
# On-Target                   3
# Off-Target                  5
# Blocked                     1
# Corners                     5
# Offsides                    1
# Free Kicks                  7
# Saves                       4
# Pass Accuracy %            90
# Passes                    629
# Distance Covered (Kms)    102
# Fouls Committed            16
# Yellow Card                 3
# Yellow & Red                0
# Red                         0
# Goals in PSO                0
# Name: 0, dtype: int64

# %%
X_test = pd.read_csv('val_X.csv')
